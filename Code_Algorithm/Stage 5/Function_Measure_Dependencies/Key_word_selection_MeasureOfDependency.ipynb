# %%
import os
import pandas as pd

# %%
os.chdir(r'/home/ccirelli2/Desktop/Docket-Sheet-Classification/Result_Ngrams')
List_dir = os.listdir(r'/home/ccirelli2/Desktop/Docket-Sheet-Classification/Result_Ngrams')
Top_word_docs = [doc for doc in List_dir if 'TopWords' in doc]

# %%
def measure_dependencies(File):
    '''
    Input  =     The location of a single Excel document that needs to be read into memory as a dataframe
    Output =     For each dataframe that is passed through this function, the return value will be the % to which 
                 the key words in all stages overlap. 
    Operations = a.) Create a list of all words in the file
                 b.) Take the len of that list. 
                 c.) Create a set of the list of key word and take its len. 
                 d.) Divide the len of the set by the len of the list and subtract the product by 1. 
                 e.) Return this value to the user as the value that represents the % of dependencies between 
                     all of the stages. 
    '''   
    # Import File 
    df = pd.read_excel(File)
    # Create list of columnnames
    df_columns = df.columns
    # Define the list to catch key words
    List_top_words = []
    # Loop over each column to obtain the key words removing any non string values (including none)
    for stage in df.columns:
        for word in df[stage]:
            if isinstance(word, str):
                List_top_words.append(word)
    # Create a set of the list of top words. 
    Set_topwords = set(List_top_words)
    
    # Calculate dependencies
    Length_list = len(List_top_words)
    Length_set = len(Set_topwords)
    Measure_dependency = (Length_list - Length_set)/Length_list
    
    return round(Measure_dependency,1)*100

# %%
def measure_dependencies_allDocs(List_dir):
    
    Dict = {}
    
    for file in List_dir:
        Measure_of_dependencies = measure_dependencies(file)
        Dict[str(file)] = Measure_of_dependencies
    
    df = pd.DataFrame(Dict, index = ['Percentage Dependency']).transpose().sort_values(
        by = 'Percentage Dependency',  ascending = True)
    
    return df

# %%
measure_dependencies_allDocs(Top_word_docs)
# Out:
#                                                     Percentage Dependency
# TopWords_Bigrams_CalculationIII_Correlation_Coe...                    0.0
# TopWords_Trigrams_CalculationII_AVG_not_zero_To...                    0.0
# TopWords_Trigrams_CalculationIII_Correlation_Co...                    0.0
# TopWords_Quadgrams_CalculationIII_Correlation_C...                    0.0
# TopWords_Bigrams_CalculationI_homebrew_STDV_Top...                    0.0
# TopWords_Quadgrams_CalculationII_AVG_not_zero_T...                    0.0
# TopWords_Bigrams_CalculationII_AVG_not_zero_Top...                    0.0
# TopWords_Trigrams_CalculationI_homebrew_STDV_To...                   10.0
# TopWords_Trigrams_CalculationII_AVG_not_zero_To...                   10.0
# TopWords_Trigrams_CalculationIII_Correlation_Co...                   10.0
# TopWords_Bigrams_CalculationII_AVG_not_zero_Top...                   10.0
# TopWords_Quadgrams_CalculationI_homebrew_STDV_T...                   10.0
# TopWords_Trigrams_CalculationI_homebrew_STDV_To...                   10.0
# TopWords_Quadgrams_CalculationI_homebrew_STDV_T...                   10.0
# TopWords_Bigrams_CalculationIII_Correlation_Coe...                   10.0
# TopWords_Quadgrams_CalculationII_AVG_not_zero_T...                   10.0
# TopWords_CalculationI_homebrew_STDV_Top15_highe...                   10.0
# TopWords_Quadgrams_CalculationIII_Correlation_C...                   20.0
# TopWords_Bigrams_CalculationII_AVG_not_zero_Top...                   20.0
# TopWords_Bigrams_CalculationI_homebrew_STDV_Top...                   20.0
# TopWords_Trigrams_CalculationII_AVG_not_zero_To...                   30.0
# TopWords_Bigrams_CalculationI_homebrew_STDV_Top...                   40.0
# TopWords_Quadgrams_CalculationII_AVG_not_zero_T...                   40.0
# TopWords_Quadgrams_CalculationII_AVG_not_zero_T...                   50.0
# TopWords_Trigrams_CalculationI_homebrew_STDV_To...                   50.0
# TopWords_Trigrams_CalculationII_AVG_not_zero_To...                   70.0
# TopWords_Quadgrams_CalculationI_homebrew_STDV_T...                   70.0
# TopWords_Bigrams_CalculationII_AVG_not_zero_Top...                   80.0
# TopWords_Bigrams_CalculationI_homebrew_STDV_Top...                   80.0
# TopWords_Quadgrams_CalculationI_homebrew_STDV_T...                   80.0
# TopWords_Trigrams_CalculationI_homebrew_STDV_To...                   80.0
